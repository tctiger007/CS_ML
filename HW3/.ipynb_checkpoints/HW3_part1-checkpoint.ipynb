# %%
#ALL OF THE FOLLOWING VARIABLES ARE SUGGESTIONS, YOU MAY NOT NEED TO USE ALL OF THESE
#ALSO, YOU MAY ADD MORE VARIABLES AS MAKE SENSE

import numpy as np
np.random.seed(100)

def sigmoid(t):
    return 1 / (1 + np.exp(-t))

def sigmoid_derivative(p):
    return p * (1 - p)

class NeuralNetwork:
    
    def _init_(self,x=np.array([[]]),y=np.array([]),numLayers=2,numNodes=2,eta=0.001,maxIter=10000):
        #create the weights from the inputs to the first layer
        #consider bias into the input matrix. x_0=1. Dimension of w^(1) is S_{j+1} x (S_j + 1)
        self.weights = [np.random.rand(numNodes,(len(x[0])+1))] 
        for i in range(numLayers-1):
            self.weights.append(np.random.rand(numNodes,(numNodes+1)) #create the random weights between internal layers
        self.weights.append(np.random.rand(1,(NumNodes+1))) #create weights from final layer to output node
        self.outputs = np.zeros(y.shape)
        self.train(learningRate=eta,maxIterations=maxIter)

    def train(self,learningRate,maxIterations):
        return 0.0

    def predict(self,x=[]):
        return 0.0

    def feedforward(self,a):
        for w in self.weights:
            self.a = sigmoid(np.dot(w,np.append([1],a)))
        return 0.0
                                
    def backprop(self,x,y):
        gdLbL = [np.zeros(w.shape) for w in self.weights]
        a = x
        a = [x]
        zs = []
        for w in self.weights:
                                
                            
                                
                                
                                
        
        delta =                         
        #activation function 
        a = x
        return 0.0
                                
    def cost_derivative(self, output, y):
        return (output-y)
                                
                                
                                
#Create an instance of the class                               
myNN = NeuralNetwork()
#investigate the class variables 
myNN.a, myNN.weights,
# Run method
myNN.feedforward()
